# %%
# %run LDA.py

# %%
pos[2]
# Out:
# 0                                      [﻿, 还好, 安装费, 有点, 贵]
# 1        [商品, 已经, 收到, 打开, 包装, 检查一下, 外观, 完美, 安装, 使用, 用后,...
# 2                                        [东西, 不错, 租房子, 足够]
# 3                                       [好, 今天, 安装, 好, 满意]
# 4                                              [能用, 好, 出租]
# 5           [安装, 材料费, 变相, 收费, 几节, pc, 管加, 几个, 弯头, 就要, 两百多]
# 6                          [后期, 一百多, 管道, 费, 插电, 一天, 度电, n]
# 7                              [安装, 完成, 未, 使用, 感觉, 外观, 不错]
# 8                            [东西, 挺, 好, 样子, 挺, 漂亮, 加热, 速度]
# 9                                     [不错, 热水器, 爸妈, 买, 方便]
# 10                        [安装, 师傅, 服务态度, 差, 点, 京东, 服务, 不错]
# 11                                         [便宜, 安装, 师傅, 好]
# 12                                 [产品, 给力, 质量, 不错, 样式, 好]
# 13       [送货, 超快, 联系, 安装, 师傅, 安装, 很快, 技术, 不错, 热水器, 没用, ...
# 14                                     [东西, 好, 觉得, 性价比, 高]
# 15          [热水器, 很大, 出水, 很快, 加热, 时间, 太, 长, 加热, 65, 度, 小时]
# ...

# %%
neg_lda

# %%
neg_lda.print_topic(0)
# Out:
# '0.042*"安装" + 0.022*"买" + 0.016*"师傅" + 0.014*"知道" + 0.010*"装" + 0.009*"好" + 0.009*"京东" + 0.007*"热水器" + 0.006*"东西" + 0.006*"美的"'

# %%
neg_lda.print_topic(1)
# Out:
# '0.025*"不错" + 0.023*"热水器" + 0.018*"好" + 0.015*"买" + 0.014*"安装" + 0.011*"加热" + 0.010*"问题" + 0.010*"东西" + 0.009*"使用" + 0.008*"京东"'

# %%
neg_lda.print_topic(2)
# Out:
# '0.056*"安装" + 0.019*"热水器" + 0.016*"不错" + 0.015*"美的" + 0.012*"好" + 0.012*"师傅" + 0.012*"买" + 0.009*"加热" + 0.007*"售后" + 0.007*"服务"'
