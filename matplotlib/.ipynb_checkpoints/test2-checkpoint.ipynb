# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import DataFrame, Series

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)

# %%
ax3 = fig.add_subplot(2, 2, 3)

# %%
plt.plot([1.5, 3.5, -2, 1.6])

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

# %%
_
# Out:
# (array([  3.,   2.,   1.,   4.,   7.,  12.,   9.,   9.,   8.,  10.,   6.,
#           6.,   8.,   4.,   3.,   3.,   3.,   0.,   1.,   1.]),
#  array([-1.94091231, -1.71276995, -1.4846276 , -1.25648525, -1.0283429 ,
#         -0.80020054, -0.57205819, -0.34391584, -0.11577348,  0.11236887,
#          0.34051122,  0.56865358,  0.79679593,  1.02493828,  1.25308064,
#          1.48122299,  1.70936534,  1.93750769,  2.16565005,  2.3937924 ,
#          2.62193475]),
#  <a list of 20 Patch objects>)

# %%
fig

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig

# %%
fig, axes = plt.subplots(2, 3)

# %%
subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-adfe015e2c02> in <module>()
# ----> 1 subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)
#
# NameError: name 'subplots_adjust' is not defined

# %%
fig

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)

# %%
plt.subplots_adjust(left=0, bottom=0, wspace=0, hspace=0)

# %%
fig
