# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import DataFrame, Series

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)

# %%
ax3 = fig.add_subplot(2, 2, 3)

# %%
plt.plot([1.5, 3.5, -2, 1.6])

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

# %%
_
# Out:
# (array([ 2.,  1.,  1.,  3.,  5.,  8.,  5.,  7.,  8.,  8.,  8.,  6.,  7.,
#          6.,  5.,  7.,  4.,  5.,  2.,  2.]),
#  array([-2.3962202 , -2.16576589, -1.93531158, -1.70485726, -1.47440295,
#         -1.24394863, -1.01349432, -0.78304   , -0.55258569, -0.32213137,
#         -0.09167706,  0.13877725,  0.36923157,  0.59968588,  0.8301402 ,
#          1.06059451,  1.29104883,  1.52150314,  1.75195746,  1.98241177,
#          2.21286609]),
#  <a list of 20 Patch objects>)

# %%
fig

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig

# %%
fig, axes = plt.subplots(2, 3)

# %%
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)

# %%
fig

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)

# %%
plt.subplots_adjust(left=0, bottom=0, wspace=0, hspace=0)

# %%
fig

# %%
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)

# %%
plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig

# %%
plt.plot(np.random.randn(30).cumsum(), 'k>--')

# %%
plt.plot(np.random.randn(30).cumsum(), 'ko--', drawstyle='steps-post', label='steps-post')

# %%
plt.xlim()
# Out:
# (0.0, 1.0)

# %%
fig

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)

# %%
ax.plot(np.random.randn(1000).cumsum())

# %%
ax

# %%
fig
